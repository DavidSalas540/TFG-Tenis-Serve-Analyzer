# %%
import pandas as pd
import numpy as np
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder

# Importamos los modelos
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
# Métricas
from sklearn.metrics import classification_report, f1_score, accuracy_score

# %%
CSV_INPUT = Path(r"C:\Users\david\Documents\TFG\train_dataset.csv") 
df = pd.read_csv(CSV_INPUT)
df.columns = df.columns.str.strip()

# %% [markdown]
# *Separamos columnas y labels*

# %% [markdown]
# *Definicion de Expertos*

# %%
# Stance
features_stance = ['knee_start', 'knee_min', 'knee_Target', 'ankle_drag_ankle', 'ankle_min_dist', 'hip_tilt']

# Effect
features_effect = ['hip_tilt', 'jump', 'impact_frame', 'lateral_offset', 'arm_extemsion']
